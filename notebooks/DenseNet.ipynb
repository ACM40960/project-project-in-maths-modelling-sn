# %% [markdown]
# # DenseNet-121
# - **Goal:** Fine-tune **DenseNet-121** on 224×224 `ImageFolder` data and evaluate with AUC + plots.
# - **Data:** `preprocessed224_best/<class_name>/*`; transforms = `ToTensor` + ImageNet **normalize**.
# - **Split:** Stratified **80/10/10** (train/val/test) via `StratifiedShuffleSplit` (class-balanced).
# - **Model:** `torchvision.models.densenet121(weights=DEFAULT)`; replace `classifier` with `Linear(..., num_classes)`.
# - **Train:** **CrossEntropy**, **Adam (1e-4)**, **AMP** (`torch.cuda.amp`), `ReduceLROnPlateau` on **val accuracy**; logs train/val **loss** & **acc**.
# - **Checkpoint:** Best by val acc → `checkpoints/densenet121_best.pth` (weights, epoch, `val_acc`, `classes`).
# - **Evaluate:** `classification_report`, **confusion matrix**, **ROC per class**, **AUC OVR** (macro/weighted/micro) with safe handling for missing classes.
# - **Plots:** Confusion matrix, per-class ROC curves, and train/val **accuracy** & **loss** curves.

# %%
import os, random
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, auc
from sklearn.preprocessing import label_binarize

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Subset
from torchvision import models, transforms, datasets

# ========= CONFIG =========
DATA_ROOT = r"preprocessed224_best"  # <-- change to your preprocessed root
BATCH_SIZE = 32
EPOCHS = 12
LR = 1e-4
NUM_WORKERS = 2
SAVE_DIR = "checkpoints"
SEED = 42
# ==========================

os.makedirs(SAVE_DIR, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# -------- Reproducibility --------
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.benchmark = True

# -------- Dataset & Transforms --------
norm_tfms = transforms.Compose([
    transforms.ToTensor(),  # already 224x224 from preprocessing
    transforms.Normalize([0.485,0.456,0.406], [0.229,0.224,0.225])
])

base_ds = datasets.ImageFolder(root=DATA_ROOT, transform=norm_tfms)
num_classes = len(base_ds.classes)
print("Classes:", base_ds.classes)

targets = np.array(base_ds.targets)
indices = np.arange(len(base_ds))

# 80/10/10 split (stratified)
# 1) train vs temp (80/20)
sss1 = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=SEED)
train_idx, temp_idx = next(sss1.split(indices, targets))
# 2) temp -> val/test (50/50 of temp = 10% each overall)
temp_targets = targets[temp_idx]
sss2 = StratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=SEED)
val_rel_idx, test_rel_idx = next(sss2.split(np.arange(len(temp_idx)), temp_targets))
val_idx  = temp_idx[val_rel_idx]
test_idx = temp_idx[test_rel_idx]

train_ds = Subset(base_ds, train_idx)
val_ds   = Subset(base_ds, val_idx)
test_ds  = Subset(base_ds, test_idx)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,
                          num_workers=NUM_WORKERS, pin_memory=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=True)
test_loader  = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=True)

print(f"Train: {len(train_ds)} | Val: {len(val_ds)} | Test: {len(test_ds)}")

# -------- Model: DenseNet-121 --------
def get_densenet121(num_classes):
    model = models.densenet121(weights=models.DenseNet121_Weights.DEFAULT)
    in_features = model.classifier.in_features
    model.classifier = nn.Linear(in_features, num_classes)
    return model

model = get_densenet121(num_classes).to(device)

# -------- Loss / Optim / Sched --------
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode="max", factor=0.5, patience=2
)
scaler = torch.cuda.amp.GradScaler(enabled=torch.cuda.is_available())

# -------- Train --------
best_val_acc = 0.0
history = {"train_loss":[], "val_loss":[], "train_acc":[], "val_acc":[]}

for epoch in range(1, EPOCHS+1):
    # train
    model.train()
    running_loss, correct, total = 0.0, 0, 0
    loop = tqdm(train_loader, desc=f"Epoch {epoch}/{EPOCHS} [Train]")
    for imgs, labels in loop:
        imgs, labels = imgs.to(device), labels.to(device)
        optimizer.zero_grad(set_to_none=True)
        with torch.cuda.amp.autocast(enabled=torch.cuda.is_available()):
            logits = model(imgs)
            loss = criterion(logits, labels)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()
        preds = logits.argmax(1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)
        loop.set_postfix(loss=loss.item(), acc=correct/max(1,total))

    train_loss = running_loss / len(train_loader)
    train_acc  = correct / total

    # validate
    model.eval()
    v_loss, v_correct, v_total = 0.0, 0, 0
    all_preds, all_labels, all_probs = [], [], []
    with torch.no_grad():
        vloop = tqdm(val_loader, desc=f"Epoch {epoch}/{EPOCHS} [Val]")
        for imgs, labels in vloop:
            imgs, labels = imgs.to(device), labels.to(device)
            with torch.cuda.amp.autocast(enabled=torch.cuda.is_available()):
                logits = model(imgs)
                loss = criterion(logits, labels)
                probs = torch.softmax(logits, dim=1)

            v_loss += loss.item()
            preds = logits.argmax(1)
            v_correct += (preds == labels).sum().item()
            v_total += labels.size(0)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

            vloop.set_postfix(loss=loss.item(), acc=v_correct/max(1,v_total))

    val_loss = v_loss / len(val_loader)
    val_acc  = v_correct / v_total

    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(train_acc)
    history["val_acc"].append(val_acc)

    print(f"✅ Epoch {epoch}: train_acc={train_acc:.4f} val_acc={val_acc:.4f} "
          f"| train_loss={train_loss:.4f} val_loss={val_loss:.4f}")

    scheduler.step(val_acc)

    # save best by val acc
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        ckpt_path = os.path.join(SAVE_DIR, "densenet121_best.pth")
        torch.save({
            "model_state": model.state_dict(),
            "val_acc": best_val_acc,
            "epoch": epoch,
            "classes": base_ds.classes
        }, ckpt_path)
        print(f"💾 Saved best model → {ckpt_path}")

# -------- Final Test Evaluation --------
print("\n=== TEST EVALUATION ===")
model.eval()
test_preds, test_labels, test_probs = [], [], []
with torch.no_grad():
    for imgs, labels in tqdm(test_loader, desc="Test"):
        imgs, labels = imgs.to(device), labels.to(device)
        with torch.cuda.amp.autocast(enabled=torch.cuda.is_available()):
            logits = model(imgs)
            probs = torch.softmax(logits, dim=1)
        preds = logits.argmax(1)

        test_preds.extend(preds.cpu().numpy())
        test_labels.extend(labels.cpu().numpy())
        test_probs.extend(probs.cpu().numpy())

print("\nClassification Report (Test):")
print(classification_report(test_labels, test_preds, digits=4, target_names=base_ds.classes))

cm = confusion_matrix(test_labels, test_preds)
plt.figure(figsize=(8,6))
plt.imshow(cm, cmap="Blues")
plt.title("Confusion Matrix - Test (DenseNet-121)")
plt.xlabel("Predicted")
plt.ylabel("True")
for (i,j),v in np.ndenumerate(cm):
    plt.text(j, i, str(v), ha='center', va='center')
plt.xticks(ticks=np.arange(num_classes), labels=base_ds.classes, rotation=45, ha="right")
plt.yticks(ticks=np.arange(num_classes), labels=base_ds.classes)
plt.tight_layout()
plt.show()

# ---- AUC (OVR) ----
classes = list(range(num_classes))
y_true_bin = label_binarize(np.array(test_labels), classes=classes)
y_score = np.array(test_probs)
present_classes = np.unique(test_labels)
present_mask = np.isin(classes, present_classes)

def safe_auc(y_true, y_score, **kwargs):
    try:
        return roc_auc_score(y_true, y_score, **kwargs)
    except ValueError:
        return float("nan")

print(f"\nAUC (macro-OVR):    {safe_auc(y_true_bin[:,present_mask], y_score[:,present_mask], average='macro', multi_class='ovr'):.4f}")
print(f"AUC (weighted-OVR): {safe_auc(y_true_bin[:,present_mask], y_score[:,present_mask], average='weighted', multi_class='ovr'):.4f}")
print(f"AUC (micro-OVR):    {safe_auc(y_true_bin[:,present_mask], y_score[:,present_mask], average='micro', multi_class='ovr'):.4f}")

plt.figure(figsize=(8,6))
for c in present_classes:
    fpr, tpr, _ = roc_curve(y_true_bin[:, c], y_score[:, c])
    class_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{base_ds.classes[c]} (AUC={class_auc:.3f})")
plt.plot([0,1],[0,1],'--')
plt.title("ROC Curves (Test) — DenseNet-121")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(fontsize=8)
plt.tight_layout()
plt.show()

# ---- Training curves ----
plt.figure(figsize=(11,4))
plt.subplot(1,2,1)
plt.plot(history["train_loss"], label="Train")
plt.plot(history["val_loss"], label="Val")
plt.title("Loss"); plt.legend()
plt.subplot(1,2,2)
plt.plot(history["train_acc"], label="Train")
plt.plot(history["val_acc"], label="Val")
plt.title("Accuracy"); plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Device: cuda
# Classes: ['ARMD', 'cataract', 'diabetic_retinopathy', 'glaucoma', 'normal']
# Train: 3782 | Val: 473 | Test: 473
# C:\Users\HP\AppData\Local\Temp\ipykernel_18368\3574741352.py:89: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=torch.cuda.is_available())
# Epoch 1/12 [Train]:   0%|                                                                      | 0/119 [00:00<?, ?it/s]C:\Users\HP\AppData\Local\Temp\ipykernel_18368\3574741352.py:103: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=torch.cuda.is_available()):
# Epoch 1/12 [Train]: 100%|█████████████████████████████████████| 119/119 [04:43<00:00,  2.38s/it, acc=0.838, loss=0.164]
# Epoch 1/12 [Val]:   0%|                                                                         | 0/15 [00:00<?, ?it/s]C:\Users\HP\AppData\Local\Temp\ipykernel_18368\3574741352.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=torch.cuda.is_available()):
# Epoch 1/12 [Val]: 100%|█████████████████████████████████████████| 15/15 [00:22<00:00,  1.51s/it, acc=0.899, loss=0.228]
# ✅ Epoch 1: train_acc=0.8382 val_acc=0.8985 | train_loss=0.4609 val_loss=0.2652
# 💾 Saved best model → checkpoints\densenet121_best.pth
# Epoch 2/12 [Train]: 100%|████████████████████████████████████| 119/119 [01:11<00:00,  1.66it/s, acc=0.941, loss=0.0371]
# Epoch 2/12 [Val]: 100%|████████████████████████████████████████| 15/15 [00:19<00:00,  1.31s/it, acc=0.896, loss=0.0886]
# ✅ Epoch 2: train_acc=0.9413 val_acc=0.8964 | train_loss=0.1659 val_loss=0.2586
# Epoch 3/12 [Train]: 100%|█████████████████████████████████████| 119/119 [01:05<00:00,  1.83it/s, acc=0.973, loss=0.253]
# Epoch 3/12 [Val]: 100%|████████████████████████████████████████| 15/15 [00:19<00:00,  1.29s/it, acc=0.924, loss=0.0906]
# ✅ Epoch 3: train_acc=0.9733 val_acc=0.9239 | train_loss=0.0878 val_loss=0.2236
# 💾 Saved best model → checkpoints\densenet121_best.pth
# Epoch 4/12 [Train]: 100%|███████████████████████████████████| 119/119 [01:05<00:00,  1.82it/s, acc=0.992, loss=0.00341]
# Epoch 4/12 [Val]: 100%|█████████████████████████████████████████| 15/15 [00:19<00:00,  1.29s/it, acc=0.93, loss=0.0377]
# ✅ Epoch 4: train_acc=0.9923 val_acc=0.9302 | train_loss=0.0320 val_loss=0.2349
# 💾 Saved best model → checkpoints\densenet121_best.pth
# Epoch 5/12 [Train]: 100%|█████████████████████████████████████| 119/119 [01:04<00:00,  1.84it/s, acc=0.991, loss=0.127]
# Epoch 5/12 [Val]: 100%|████████████████████████████████████████| 15/15 [00:19<00:00,  1.27s/it, acc=0.928, loss=0.0317]
# ✅ Epoch 5: train_acc=0.9907 val_acc=0.9281 | train_loss=0.0339 val_loss=0.2949
# Epoch 6/12 [Train]: 100%|████████████████████████████████████| 119/119 [01:03<00:00,  1.87it/s, acc=0.987, loss=0.0888]
# Epoch 6/12 [Val]: 100%|█████████████████████████████████████████| 15/15 [00:18<00:00,  1.21s/it, acc=0.934, loss=0.264]
# ✅ Epoch 6: train_acc=0.9873 val_acc=0.9345 | train_loss=0.0416 val_loss=0.2338
# 💾 Saved best model → checkpoints\densenet121_best.pth
# Epoch 7/12 [Train]: 100%|█████████████████████████████████████| 119/119 [01:03<00:00,  1.88it/s, acc=0.994, loss=0.128]
# Epoch 7/12 [Val]: 100%|█████████████████████████████████████████| 15/15 [00:18<00:00,  1.22s/it, acc=0.932, loss=0.226]
# ✅ Epoch 7: train_acc=0.9942 val_acc=0.9323 | train_loss=0.0275 val_loss=0.2509
# Epoch 8/12 [Train]: 100%|█████████████████████████████████████| 119/119 [01:04<00:00,  1.85it/s, acc=0.998, loss=0.293]
# Epoch 8/12 [Val]: 100%|████████████████████████████████████████| 15/15 [00:18<00:00,  1.23s/it, acc=0.926, loss=0.0381]
# ✅ Epoch 8: train_acc=0.9984 val_acc=0.9260 | train_loss=0.0132 val_loss=0.2901
# Epoch 9/12 [Train]: 100%|████████████████████████████████████| 119/119 [01:03<00:00,  1.88it/s, acc=0.999, loss=0.0976]
# Epoch 9/12 [Val]: 100%|████████████████████████████████████████| 15/15 [00:18<00:00,  1.23s/it, acc=0.928, loss=0.0345]
# ✅ Epoch 9: train_acc=0.9992 val_acc=0.9281 | train_loss=0.0062 val_loss=0.3037
# Epoch 10/12 [Train]: 100%|████████████████████████████████████| 119/119 [01:03<00:00,  1.86it/s, acc=0.998, loss=0.091]
# Epoch 10/12 [Val]: 100%|███████████████████████████████████████| 15/15 [00:18<00:00,  1.21s/it, acc=0.932, loss=0.0218]
# ✅ Epoch 10: train_acc=0.9984 val_acc=0.9323 | train_loss=0.0055 val_loss=0.2989
# Epoch 11/12 [Train]: 100%|████████████████████████████████████| 119/119 [01:03<00:00,  1.87it/s, acc=0.998, loss=0.262]
# Epoch 11/12 [Val]: 100%|█████████████████████████████████████████| 15/15 [00:18<00:00,  1.23s/it, acc=0.93, loss=0.052]
# ✅ Epoch 11: train_acc=0.9981 val_acc=0.9302 | train_loss=0.0075 val_loss=0.2757
# Epoch 12/12 [Train]: 100%|██████████████████████████████████| 119/119 [01:03<00:00,  1.87it/s, acc=0.998, loss=0.00144]
# Epoch 12/12 [Val]: 100%|███████████████████████████████████████| 15/15 [00:18<00:00,  1.23s/it, acc=0.937, loss=0.0116]
# ✅ Epoch 12: train_acc=0.9984 val_acc=0.9366 | train_loss=0.0110 val_loss=0.2669
# 💾 Saved best model → checkpoints\densenet121_best.pth
#
# === TEST EVALUATION ===
# Test:   0%|                                                                                     | 0/15 [00:00<?, ?it/s]C:\Users\HP\AppData\Local\Temp\ipykernel_18368\3574741352.py:175: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=torch.cuda.is_available()):
# Test: 100%|████████████████████████████████████████████████████████████████████████████| 15/15 [00:18<00:00,  1.21s/it]
# Classification Report (Test):
#                       precision    recall  f1-score   support
#
#                 ARMD     1.0000    1.0000    1.0000        51
#             cataract     0.9074    0.9423    0.9245       104
# diabetic_retinopathy     0.9910    1.0000    0.9955       110
#             glaucoma     0.9213    0.8119    0.8632       101
#               normal     0.8684    0.9252    0.8959       107
#
#             accuracy                         0.9302       473
#            macro avg     0.9376    0.9359    0.9358       473
#         weighted avg     0.9310    0.9302    0.9296       473
# AUC (macro-OVR):    0.9936
# AUC (weighted-OVR): 0.9930
# AUC (micro-OVR):    0.9952

# %% [markdown]
# # DenseNet-169
# - **Goal:** Fine-tune **DenseNet-169** on 224×224 `ImageFolder` data and evaluate with AUC + plots.
# - **Data:** `preprocessed224_best/<class_name>/*`; transforms = `ToTensor` + ImageNet **Normalize**.
# - **Split:** Stratified **80/10/10** (train/val/test) via `StratifiedShuffleSplit` (class-balanced).
# - **Model:** `torchvision.models.densenet169(weights=DEFAULT)`; replace `classifier` with `Linear(..., num_classes)`.
# - **Train:** **CrossEntropy**, **Adam (1e-4)**, **AMP** (`torch.amp.autocast` + `GradScaler`), `ReduceLROnPlateau` on **val accuracy**; logs train/val **loss** & **acc**.
# - **Checkpoint:** Best by val acc → `checkpoints/densenet169_best.pth` (weights, epoch, `val_acc`, `classes`).
# - **Evaluate:** `classification_report`, **confusion matrix**, **ROC per class**, **AUC OVR** (macro/weighted/micro) with safe handling for missing classes.
# - **Plots:** Confusion matrix, per-class ROC curves, and train/val **accuracy** & **loss** curves.

# %%
import os, random
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
from torchvision import models, transforms, datasets
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Subset

# ======== CONFIG ========
DATA_ROOT   = r"preprocessed224_best"  # <-- change me
BATCH_SIZE  = 32
EPOCHS      = 12
LR          = 1e-4
NUM_WORKERS = 2
SAVE_DIR    = "checkpoints"
SEED        = 42
# ========================

os.makedirs(SAVE_DIR, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# Repro
random.seed(SEED); np.random.seed(SEED)
torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.benchmark = True

# Dataset & transforms (already 224x224)
norm_tfms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
])
base_ds = datasets.ImageFolder(root=DATA_ROOT, transform=norm_tfms)
num_classes = len(base_ds.classes)
print("Classes:", base_ds.classes)

targets = np.array(base_ds.targets)
indices = np.arange(len(base_ds))

# 80/10/10 split: (80/20) then (10/10)
sss1 = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=SEED)
train_idx, temp_idx = next(sss1.split(indices, targets))
temp_targets = targets[temp_idx]
sss2 = StratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=SEED)
val_rel, test_rel = next(sss2.split(np.arange(len(temp_idx)), temp_targets))
val_idx, test_idx = temp_idx[val_rel], temp_idx[test_rel]

train_ds = Subset(base_ds, train_idx)
val_ds   = Subset(base_ds, val_idx)
test_ds  = Subset(base_ds, test_idx)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,
                          num_workers=NUM_WORKERS, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=True)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=True)

print(f"Train: {len(train_ds)} | Val: {len(val_ds)} | Test: {len(test_ds)}")

# Model: DenseNet-169
def get_densenet169(num_classes):
    model = models.densenet169(weights=models.DenseNet169_Weights.DEFAULT)
    in_feats = model.classifier.in_features
    model.classifier = nn.Linear(in_feats, num_classes)
    return model

model = get_densenet169(num_classes).to(device)

# Loss/Optim/Sched
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="max", factor=0.5, patience=2)
scaler = torch.amp.GradScaler("cuda", enabled=torch.cuda.is_available())

# Train
best_val_acc = 0.0
history = {"train_loss":[], "val_loss":[], "train_acc":[], "val_acc":[]}

for epoch in range(1, EPOCHS+1):
    # ---- Train ----
    model.train()
    running_loss, correct, total = 0.0, 0, 0
    for imgs, labels in tqdm(train_loader, desc=f"Epoch {epoch}/{EPOCHS} [Train]"):
        imgs, labels = imgs.to(device), labels.to(device)
        optimizer.zero_grad(set_to_none=True)
        with torch.amp.autocast("cuda", enabled=torch.cuda.is_available()):
            logits = model(imgs)
            loss = criterion(logits, labels)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()
        preds = logits.argmax(1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    train_loss = running_loss / max(1, len(train_loader))
    train_acc  = correct / max(1, total)

    # ---- Val ----
    model.eval()
    v_loss, v_correct, v_total = 0.0, 0, 0
    all_preds, all_labels, all_probs = [], [], []
    with torch.no_grad():
        for imgs, labels in tqdm(val_loader, desc=f"Epoch {epoch}/{EPOCHS} [Val]"):
            imgs, labels = imgs.to(device), labels.to(device)
            with torch.amp.autocast("cuda", enabled=torch.cuda.is_available()):
                logits = model(imgs)
                loss = criterion(logits, labels)
                probs = torch.softmax(logits, dim=1)
            v_loss += loss.item()
            preds = logits.argmax(1)
            v_correct += (preds == labels).sum().item()
            v_total += labels.size(0)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    val_loss = v_loss / max(1, len(val_loader))
    val_acc  = v_correct / max(1, v_total)

    history["train_loss"].append(train_loss); history["val_loss"].append(val_loss)
    history["train_acc"].append(train_acc);   history["val_acc"].append(val_acc)

    print(f"✅ Epoch {epoch}: train_acc={train_acc:.4f} val_acc={val_acc:.4f} | "
          f"train_loss={train_loss:.4f} val_loss={val_loss:.4f}")

    scheduler.step(val_acc)

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        ckpt_path = os.path.join(SAVE_DIR, "densenet169_best.pth")
        torch.save({"model_state": model.state_dict(),
                    "val_acc": best_val_acc,
                    "epoch": epoch,
                    "classes": base_ds.classes}, ckpt_path)
        print(f"💾 Saved best model → {ckpt_path}")

# ---- Final Test Eval ----
print("\n=== TEST EVALUATION (DenseNet-169) ===")
model.eval()
test_preds, test_labels, test_probs = [], [], []
with torch.no_grad():
    for imgs, labels in tqdm(test_loader, desc="Test"):
        imgs, labels = imgs.to(device), labels.to(device)
        with torch.amp.autocast("cuda", enabled=torch.cuda.is_available()):
            logits = model(imgs)
            probs = torch.softmax(logits, dim=1)
        preds = logits.argmax(1)
        test_preds.extend(preds.cpu().numpy())
        test_labels.extend(labels.cpu().numpy())
        test_probs.extend(probs.cpu().numpy())

print("\nClassification Report (Test):")
print(classification_report(test_labels, test_preds, digits=4, target_names=base_ds.classes))

cm = confusion_matrix(test_labels, test_preds)
plt.figure(figsize=(8,6))
plt.imshow(cm, cmap="Blues")
plt.title("Confusion Matrix - Test (DenseNet-169)")
plt.xlabel("Predicted"); plt.ylabel("True")
for (i,j),v in np.ndenumerate(cm):
    plt.text(j, i, str(v), ha='center', va='center')
plt.xticks(ticks=np.arange(num_classes), labels=base_ds.classes, rotation=45, ha="right")
plt.yticks(ticks=np.arange(num_classes), labels=base_ds.classes)
plt.tight_layout(); plt.show()

# AUC + ROC
classes = list(range(num_classes))
y_true_bin = label_binarize(np.array(test_labels), classes=classes)
y_score = np.array(test_probs)
present_classes = np.unique(test_labels)
present_mask = np.isin(classes, present_classes)

def safe_auc(y_true, y_score, **kwargs):
    try:
        return roc_auc_score(y_true, y_score, **kwargs)
    except ValueError:
        return float("nan")

print(f"\nAUC (macro-OVR):    {safe_auc(y_true_bin[:,present_mask], y_score[:,present_mask], average='macro',    multi_class='ovr'):.4f}")
print(f"AUC (weighted-OVR): {safe_auc(y_true_bin[:,present_mask], y_score[:,present_mask], average='weighted', multi_class='ovr'):.4f}")
print(f"AUC (micro-OVR):    {safe_auc(y_true_bin[:,present_mask], y_score[:,present_mask], average='micro',    multi_class='ovr'):.4f}")

plt.figure(figsize=(8,6))
for c in present_classes:
    fpr, tpr, _ = roc_curve(y_true_bin[:, c], y_score[:, c])
    class_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{base_ds.classes[c]} (AUC={class_auc:.3f})")
plt.plot([0,1],[0,1],'--')
plt.title("ROC Curves — Test (DenseNet-169)")
plt.xlabel("False Positive Rate"); plt.ylabel("True Positive Rate")
plt.legend(fontsize=8); plt.tight_layout(); plt.show()

# Train/Val curves (Accuracy & Loss)
plt.figure(figsize=(11,4))
plt.subplot(1,2,1)
plt.plot(history["train_acc"], label="Train")
plt.plot(history["val_acc"],   label="Val")
plt.title("Accuracy"); plt.xlabel("Epoch"); plt.ylabel("Acc"); plt.legend()
plt.subplot(1,2,2)
plt.plot(history["train_loss"], label="Train")
plt.plot(history["val_loss"],   label="Val")
plt.title("Loss"); plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.legend()
plt.tight_layout(); plt.show()
# Out:
# Device: cuda
# Classes: ['ARMD', 'cataract', 'diabetic_retinopathy', 'glaucoma', 'normal']
# Train: 3782 | Val: 473 | Test: 473
# Epoch 1/12 [Train]: 100%|████████████████████████████████████████████████████████████| 119/119 [04:38<00:00,  2.34s/it]
# Epoch 1/12 [Val]: 100%|████████████████████████████████████████████████████████████████| 15/15 [00:17<00:00,  1.16s/it]
# ✅ Epoch 1: train_acc=0.8596 val_acc=0.9112 | train_loss=0.4020 val_loss=0.2198
# 💾 Saved best model → checkpoints\densenet169_best.pth
# Epoch 2/12 [Train]: 100%|████████████████████████████████████████████████████████████| 119/119 [04:49<00:00,  2.43s/it]
# Epoch 2/12 [Val]: 100%|████████████████████████████████████████████████████████████████| 15/15 [00:22<00:00,  1.50s/it]
# ✅ Epoch 2: train_acc=0.9492 val_acc=0.9281 | train_loss=0.1447 val_loss=0.1854
# 💾 Saved best model → checkpoints\densenet169_best.pth
# Epoch 3/12 [Train]: 100%|████████████████████████████████████████████████████████████| 119/119 [04:50<00:00,  2.44s/it]
# Epoch 3/12 [Val]: 100%|████████████████████████████████████████████████████████████████| 15/15 [00:20<00:00,  1.40s/it]
# ✅ Epoch 3: train_acc=0.9733 val_acc=0.9091 | train_loss=0.0846 val_loss=0.2189
# Epoch 4/12 [Train]: 100%|████████████████████████████████████████████████████████████| 119/119 [04:49<00:00,  2.43s/it]
# Epoch 4/12 [Val]: 100%|████████████████████████████████████████████████████████████████| 15/15 [00:20<00:00,  1.36s/it]
# ✅ Epoch 4: train_acc=0.9907 val_acc=0.9239 | train_loss=0.0376 val_loss=0.2220
# Epoch 5/12 [Train]: 100%|████████████████████████████████████████████████████████████| 119/119 [04:49<00:00,  2.43s/it]
# Epoch 5/12 [Val]: 100%|████████████████████████████████████████████████████████████████| 15/15 [00:20<00:00,  1.38s/it]
# ✅ Epoch 5: train_acc=0.9905 val_acc=0.9345 | train_loss=0.0381 val_loss=0.2308
# 💾 Saved best model → checkpoints\densenet169_best.pth
# Epoch 6/12 [Train]: 100%|████████████████████████████████████████████████████████████| 119/119 [04:48<00:00,  2.43s/it]
# Epoch 6/12 [Val]: 100%|████████████████████████████████████████████████████████████████| 15/15 [00:20<00:00,  1.40s/it]
# ✅ Epoch 6: train_acc=0.9894 val_acc=0.9323 | train_loss=0.0348 val_loss=0.2146
# Epoch 7/12 [Train]: 100%|████████████████████████████████████████████████████████████| 119/119 [04:50<00:00,  2.44s/it]
# Epoch 7/12 [Val]: 100%|████████████████████████████████████████████████████████████████| 15/15 [00:20<00:00,  1.37s/it]
# ✅ Epoch 7: train_acc=0.9934 val_acc=0.9218 | train_loss=0.0215 val_loss=0.2494
# Epoch 8/12 [Train]: 100%|████████████████████████████████████████████████████████████| 119/119 [04:49<00:00,  2.43s/it]
# Epoch 8/12 [Val]: 100%|████████████████████████████████████████████████████████████████| 15/15 [00:20<00:00,  1.36s/it]
# ✅ Epoch 8: train_acc=0.9934 val_acc=0.9281 | train_loss=0.0211 val_loss=0.2201
# Epoch 9/12 [Train]: 100%|████████████████████████████████████████████████████████████| 119/119 [04:49<00:00,  2.43s/it]
# Epoch 9/12 [Val]: 100%|████████████████████████████████████████████████████████████████| 15/15 [00:20<00:00,  1.36s/it]
# ✅ Epoch 9: train_acc=0.9984 val_acc=0.9387 | train_loss=0.0078 val_loss=0.2489
# 💾 Saved best model → checkpoints\densenet169_best.pth
# Epoch 10/12 [Train]: 100%|███████████████████████████████████████████████████████████| 119/119 [04:48<00:00,  2.43s/it]
# Epoch 10/12 [Val]: 100%|███████████████████████████████████████████████████████████████| 15/15 [00:20<00:00,  1.36s/it]
# ✅ Epoch 10: train_acc=0.9992 val_acc=0.9387 | train_loss=0.0056 val_loss=0.2343
# Epoch 11/12 [Train]: 100%|███████████████████████████████████████████████████████████| 119/119 [05:00<00:00,  2.53s/it]
# Epoch 11/12 [Val]: 100%|███████████████████████████████████████████████████████████████| 15/15 [00:20<00:00,  1.39s/it]
# ✅ Epoch 11: train_acc=0.9992 val_acc=0.9345 | train_loss=0.0033 val_loss=0.2600
# Epoch 12/12 [Train]: 100%|███████████████████████████████████████████████████████████| 119/119 [05:12<00:00,  2.62s/it]
# Epoch 12/12 [Val]: 100%|███████████████████████████████████████████████████████████████| 15/15 [00:22<00:00,  1.48s/it]
# ✅ Epoch 12: train_acc=0.9995 val_acc=0.9345 | train_loss=0.0030 val_loss=0.2522
#
# === TEST EVALUATION (DenseNet-169) ===
# Test: 100%|████████████████████████████████████████████████████████████████████████████| 15/15 [00:23<00:00,  1.60s/it]
# Classification Report (Test):
#                       precision    recall  f1-score   support
#
#                 ARMD     1.0000    1.0000    1.0000        51
#             cataract     0.9381    0.8750    0.9055       104
# diabetic_retinopathy     0.9910    1.0000    0.9955       110
#             glaucoma     0.8713    0.8713    0.8713       101
#               normal     0.8850    0.9346    0.9091       107
#
#             accuracy                         0.9302       473
#            macro avg     0.9371    0.9362    0.9363       473
#         weighted avg     0.9308    0.9302    0.9301       473
# AUC (macro-OVR):    0.9914
# AUC (weighted-OVR): 0.9905
# AUC (micro-OVR):    0.9936

# %% [markdown]
# # DenseNet-201
#
#
# - **Goal:** Fine-tune **DenseNet-201** on 224×224 `ImageFolder` data; evaluate with AUC + plots.
# - **Data:** `preprocessed224_best/<class_name>/*`; transforms = `ToTensor` + ImageNet **Normalize**.
# - **Split:** Stratified **80/10/10** (train/val/test) via `StratifiedShuffleSplit` (class-balanced).
# - **Model:** `torchvision.models.densenet201(weights=DEFAULT)`; replace `classifier` with `Linear(..., num_classes)`.
# - **Train:** **CrossEntropy**, **Adam (1e-4)**, **AMP** (`torch.amp.autocast` + `GradScaler`), `ReduceLROnPlateau` on **val acc**; logs train/val **loss** & **acc**.
# - **Checkpoint:** Best by val acc → `checkpoints/densenet201_best.pth` (weights, epoch, `val_acc`, `classes`).
# - **Evaluate:** `classification_report`, **confusion matrix**, **ROC per class**, **AUC OVR** (macro/weighted/micro) with safe handling for missing classes.
# - **Plots:** Confusion matrix, per-class ROC curves, and train/val **accuracy** & **loss** curves.

# %%
import os, random
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
from torchvision import models, transforms, datasets
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Subset

# ======== CONFIG ========
DATA_ROOT   = r"preprocessed224_best"  # <-- change me
BATCH_SIZE  = 32
EPOCHS      = 12
LR          = 1e-4
NUM_WORKERS = 2
SAVE_DIR    = "checkpoints"
SEED        = 42
# ========================

os.makedirs(SAVE_DIR, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# Repro
random.seed(SEED); np.random.seed(SEED)
torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.benchmark = True

# Dataset & transforms
norm_tfms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
])
base_ds = datasets.ImageFolder(root=DATA_ROOT, transform=norm_tfms)
num_classes = len(base_ds.classes)
print("Classes:", base_ds.classes)

targets = np.array(base_ds.targets)
indices = np.arange(len(base_ds))

# 80/10/10 split
sss1 = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=SEED)
train_idx, temp_idx = next(sss1.split(indices, targets))
temp_targets = targets[temp_idx]
sss2 = StratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=SEED)
val_rel, test_rel = next(sss2.split(np.arange(len(temp_idx)), temp_targets))
val_idx, test_idx = temp_idx[val_rel], temp_idx[test_rel]

train_ds = Subset(base_ds, train_idx)
val_ds   = Subset(base_ds, val_idx)
test_ds  = Subset(base_ds, test_idx)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,
                          num_workers=NUM_WORKERS, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=True)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=True)

print(f"Train: {len(train_ds)} | Val: {len(val_ds)} | Test: {len(test_ds)}")

# Model: DenseNet-201
def get_densenet201(num_classes):
    model = models.densenet201(weights=models.DenseNet201_Weights.DEFAULT)
    in_feats = model.classifier.in_features
    model.classifier = nn.Linear(in_feats, num_classes)
    return model

model = get_densenet201(num_classes).to(device)

# Loss/Optim/Sched
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="max", factor=0.5, patience=2)
scaler = torch.amp.GradScaler("cuda", enabled=torch.cuda.is_available())

# Train
best_val_acc = 0.0
history = {"train_loss":[], "val_loss":[], "train_acc":[], "val_acc":[]}

for epoch in range(1, EPOCHS+1):
    # ---- Train ----
    model.train()
    running_loss, correct, total = 0.0, 0, 0
    for imgs, labels in tqdm(train_loader, desc=f"Epoch {epoch}/{EPOCHS} [Train]"):
        imgs, labels = imgs.to(device), labels.to(device)
        optimizer.zero_grad(set_to_none=True)
        with torch.amp.autocast("cuda", enabled=torch.cuda.is_available()):
            logits = model(imgs)
            loss = criterion(logits, labels)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()
        preds = logits.argmax(1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    train_loss = running_loss / max(1, len(train_loader))
    train_acc  = correct / max(1, total)

    # ---- Val ----
    model.eval()
    v_loss, v_correct, v_total = 0.0, 0, 0
    all_preds, all_labels, all_probs = [], [], []
    with torch.no_grad():
        for imgs, labels in tqdm(val_loader, desc=f"Epoch {epoch}/{EPOCHS} [Val]"):
            imgs, labels = imgs.to(device), labels.to(device)
            with torch.amp.autocast("cuda", enabled=torch.cuda.is_available()):
                logits = model(imgs)
                loss = criterion(logits, labels)
                probs = torch.softmax(logits, dim=1)
            v_loss += loss.item()
            preds = logits.argmax(1)
            v_correct += (preds == labels).sum().item()
            v_total += labels.size(0)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    val_loss = v_loss / max(1, len(val_loader))
    val_acc  = v_correct / max(1, v_total)

    history["train_loss"].append(train_loss); history["val_loss"].append(val_loss)
    history["train_acc"].append(train_acc);   history["val_acc"].append(val_acc)

    print(f"✅ Epoch {epoch}: train_acc={train_acc:.4f} val_acc={val_acc:.4f} | "
          f"train_loss={train_loss:.4f} val_loss={val_loss:.4f}")

    scheduler.step(val_acc)

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        ckpt_path = os.path.join(SAVE_DIR, "densenet201_best.pth")
        torch.save({"model_state": model.state_dict(),
                    "val_acc": best_val_acc,
                    "epoch": epoch,
                    "classes": base_ds.classes}, ckpt_path)
        print(f"💾 Saved best model → {ckpt_path}")

# ---- Final Test Eval ----
print("\n=== TEST EVALUATION (DenseNet-201) ===")
model.eval()
test_preds, test_labels, test_probs = [], [], []
with torch.no_grad():
    for imgs, labels in tqdm(test_loader, desc="Test"):
        imgs, labels = imgs.to(device), labels.to(device)
        with torch.amp.autocast("cuda", enabled=torch.cuda.is_available()):
            logits = model(imgs)
            probs = torch.softmax(logits, dim=1)
        preds = logits.argmax(1)
        test_preds.extend(preds.cpu().numpy())
        test_labels.extend(labels.cpu().numpy())
        test_probs.extend(probs.cpu().numpy())

print("\nClassification Report (Test):")
print(classification_report(test_labels, test_preds, digits=4, target_names=base_ds.classes))

cm = confusion_matrix(test_labels, test_preds)
plt.figure(figsize=(8,6))
plt.imshow(cm, cmap="Blues")
plt.title("Confusion Matrix - Test (DenseNet-201)")
plt.xlabel("Predicted"); plt.ylabel("True")
for (i,j),v in np.ndenumerate(cm):
    plt.text(j, i, str(v), ha='center', va='center')
plt.xticks(ticks=np.arange(num_classes), labels=base_ds.classes, rotation=45, ha="right")
plt.yticks(ticks=np.arange(num_classes), labels=base_ds.classes)
plt.tight_layout(); plt.show()

# AUC + ROC
classes = list(range(num_classes))
y_true_bin = label_binarize(np.array(test_labels), classes=classes)
y_score = np.array(test_probs)
present_classes = np.unique(test_labels)
present_mask = np.isin(classes, present_classes)

def safe_auc(y_true, y_score, **kwargs):
    try:
        return roc_auc_score(y_true, y_score, **kwargs)
    except ValueError:
        return float("nan")

print(f"\nAUC (macro-OVR):    {safe_auc(y_true_bin[:,present_mask], y_score[:,present_mask], average='macro',    multi_class='ovr'):.4f}")
print(f"AUC (weighted-OVR): {safe_auc(y_true_bin[:,present_mask], y_score[:,present_mask], average='weighted', multi_class='ovr'):.4f}")
print(f"AUC (micro-OVR):    {safe_auc(y_true_bin[:,present_mask], y_score[:,present_mask], average='micro',    multi_class='ovr'):.4f}")

plt.figure(figsize=(8,6))
for c in present_classes:
    fpr, tpr, _ = roc_curve(y_true_bin[:, c], y_score[:, c])
    class_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{base_ds.classes[c]} (AUC={class_auc:.3f})")
plt.plot([0,1],[0,1],'--')
plt.title("ROC Curves — Test (DenseNet-201)")
plt.xlabel("False Positive Rate"); plt.ylabel("True Positive Rate")
plt.legend(fontsize=8); plt.tight_layout(); plt.show()

# Train/Val curves (Accuracy & Loss)
plt.figure(figsize=(11,4))
plt.subplot(1,2,1)
plt.plot(history["train_acc"], label="Train")
plt.plot(history["val_acc"],   label="Val")
plt.title("Accuracy"); plt.xlabel("Epoch"); plt.ylabel("Acc"); plt.legend()
plt.subplot(1,2,2)
plt.plot(history["train_loss"], label="Train")
plt.plot(history["val_loss"],   label="Val")
plt.title("Loss"); plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.legend()
plt.tight_layout(); plt.show()
# Out:
# Device: cuda
# Classes: ['ARMD', 'cataract', 'diabetic_retinopathy', 'glaucoma', 'normal']
# Train: 3782 | Val: 473 | Test: 473
# Epoch 1/12 [Train]: 100%|████████████████████████████████████████████████████████████| 119/119 [06:40<00:00,  3.37s/it]
# Epoch 1/12 [Val]: 100%|████████████████████████████████████████████████████████████████| 15/15 [00:18<00:00,  1.25s/it]
# ✅ Epoch 1: train_acc=0.8622 val_acc=0.9133 | train_loss=0.3923 val_loss=0.2283
# 💾 Saved best model → checkpoints\densenet201_best.pth
# Epoch 2/12 [Train]: 100%|████████████████████████████████████████████████████████████| 119/119 [07:06<00:00,  3.58s/it]
# Epoch 2/12 [Val]: 100%|████████████████████████████████████████████████████████████████| 15/15 [00:24<00:00,  1.62s/it]
# ✅ Epoch 2: train_acc=0.9527 val_acc=0.9239 | train_loss=0.1376 val_loss=0.2113
# 💾 Saved best model → checkpoints\densenet201_best.pth
# Epoch 3/12 [Train]: 100%|████████████████████████████████████████████████████████████| 119/119 [07:06<00:00,  3.59s/it]
# Epoch 3/12 [Val]: 100%|████████████████████████████████████████████████████████████████| 15/15 [00:24<00:00,  1.63s/it]
# ✅ Epoch 3: train_acc=0.9736 val_acc=0.9302 | train_loss=0.0822 val_loss=0.2046
# 💾 Saved best model → checkpoints\densenet201_best.pth
# Epoch 4/12 [Train]: 100%|████████████████████████████████████████████████████████████| 119/119 [07:06<00:00,  3.58s/it]
# Epoch 4/12 [Val]: 100%|████████████████████████████████████████████████████████████████| 15/15 [00:24<00:00,  1.63s/it]
# ✅ Epoch 4: train_acc=0.9870 val_acc=0.9218 | train_loss=0.0481 val_loss=0.2454
# Epoch 5/12 [Train]: 100%|████████████████████████████████████████████████████████████| 119/119 [07:06<00:00,  3.59s/it]
# Epoch 5/12 [Val]: 100%|████████████████████████████████████████████████████████████████| 15/15 [00:24<00:00,  1.64s/it]
# ✅ Epoch 5: train_acc=0.9937 val_acc=0.9323 | train_loss=0.0246 val_loss=0.2249
# 💾 Saved best model → checkpoints\densenet201_best.pth
# Epoch 6/12 [Train]: 100%|████████████████████████████████████████████████████████████| 119/119 [07:08<00:00,  3.60s/it]
# Epoch 6/12 [Val]: 100%|████████████████████████████████████████████████████████████████| 15/15 [00:27<00:00,  1.82s/it]
# ✅ Epoch 6: train_acc=0.9944 val_acc=0.9239 | train_loss=0.0238 val_loss=0.2568
# Epoch 7/12 [Train]: 100%|████████████████████████████████████████████████████████████| 119/119 [07:34<00:00,  3.82s/it]
# Epoch 7/12 [Val]: 100%|████████████████████████████████████████████████████████████████| 15/15 [00:25<00:00,  1.71s/it]
# ✅ Epoch 7: train_acc=0.9889 val_acc=0.9197 | train_loss=0.0293 val_loss=0.2708
# Epoch 8/12 [Train]: 100%|████████████████████████████████████████████████████████████| 119/119 [07:20<00:00,  3.70s/it]
# Epoch 8/12 [Val]: 100%|████████████████████████████████████████████████████████████████| 15/15 [00:25<00:00,  1.69s/it]
# ✅ Epoch 8: train_acc=0.9952 val_acc=0.9302 | train_loss=0.0169 val_loss=0.3219
# Epoch 9/12 [Train]: 100%|████████████████████████████████████████████████████████████| 119/119 [07:50<00:00,  3.96s/it]
# Epoch 9/12 [Val]: 100%|████████████████████████████████████████████████████████████████| 15/15 [00:34<00:00,  2.32s/it]
# ✅ Epoch 9: train_acc=0.9974 val_acc=0.9323 | train_loss=0.0095 val_loss=0.2994
# Epoch 10/12 [Train]: 100%|███████████████████████████████████████████████████████████| 119/119 [08:11<00:00,  4.13s/it]
# Epoch 10/12 [Val]: 100%|███████████████████████████████████████████████████████████████| 15/15 [00:25<00:00,  1.69s/it]
# ✅ Epoch 10: train_acc=0.9992 val_acc=0.9387 | train_loss=0.0039 val_loss=0.3061
# 💾 Saved best model → checkpoints\densenet201_best.pth
# Epoch 11/12 [Train]: 100%|███████████████████████████████████████████████████████████| 119/119 [07:16<00:00,  3.67s/it]
# Epoch 11/12 [Val]: 100%|███████████████████████████████████████████████████████████████| 15/15 [00:25<00:00,  1.72s/it]
# ✅ Epoch 11: train_acc=0.9992 val_acc=0.9323 | train_loss=0.0038 val_loss=0.3346
# Epoch 12/12 [Train]: 100%|███████████████████████████████████████████████████████████| 119/119 [08:42<00:00,  4.39s/it]
# Epoch 12/12 [Val]: 100%|███████████████████████████████████████████████████████████████| 15/15 [00:31<00:00,  2.11s/it]
# ✅ Epoch 12: train_acc=0.9987 val_acc=0.9323 | train_loss=0.0041 val_loss=0.3234
#
# === TEST EVALUATION (DenseNet-201) ===
# Test: 100%|████████████████████████████████████████████████████████████████████████████| 15/15 [00:28<00:00,  1.91s/it]
# Classification Report (Test):
#                       precision    recall  f1-score   support
#
#                 ARMD     1.0000    1.0000    1.0000        51
#             cataract     0.9223    0.9135    0.9179       104
# diabetic_retinopathy     0.9910    1.0000    0.9955       110
#             glaucoma     0.8750    0.8317    0.8528       101
#               normal     0.8839    0.9252    0.9041       107
#
#             accuracy                         0.9281       473
#            macro avg     0.9344    0.9341    0.9341       473
#         weighted avg     0.9279    0.9281    0.9278       473
# AUC (macro-OVR):    0.9905
# AUC (weighted-OVR): 0.9896
# AUC (micro-OVR):    0.9934
