# %% [markdown]
# # Resnet-50 and 101
# * **Data**: Loads ImageFolder from preprocessed224_best/; ImageNet normalization; stratified 80/10/10 split (train/val/test).
#
# * **Model**: resnet50 or resnet101 with ImageNet weights; final fc replaced to match num_classes.
#
# ## Training:
#
# * **Loss**: CrossEntropyLoss
#
# * **Optimizer**: Adam (lr=1e-4) + ReduceLROnPlateau on val acc
#
# * Mixed precision on train (cuda.amp scaler/autocast); progress via tqdm
#
# * Tracks train/val loss and accuracy; saves best checkpoint to checkpoints/<MODEL_NAME>_best.pth.
#
# * **Validation/Test**: FP32 forward (logits clamped to [-100, 100] for numerical safety).
#
# ## Reporting:
#
# * Classification report (precision/recall/F1 per class)
#
# * Confusion matrix heatmap
#
# * AUC (OVR): macro / weighted / micro, plus per-class ROC curves
#
# * Training curves: loss & accuracy over epochs
#
# * Config knobs: MODEL_NAME (resnet50/resnet101), BATCH_SIZE, EPOCHS, LR, SEED, DATA_ROOT.

# %% [markdown]
# ### ResNet-50

# %%
import os, random
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, auc
from sklearn.preprocessing import label_binarize

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Subset
from torchvision import models, transforms, datasets

# ========= CONFIG =========
DATA_ROOT   = r"preprocessed224_best"
BATCH_SIZE  = 32
EPOCHS      = 12
LR          = 1e-4
NUM_WORKERS = 2
SAVE_DIR    = "checkpoints"
SEED        = 42
MODEL_NAME  = "resnet50"   
# ==========================

os.makedirs(SAVE_DIR, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# -------- Reproducibility --------
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.benchmark = True

# -------- Dataset & Transforms --------
norm_tfms = transforms.Compose([
    transforms.ToTensor(),  # already 224x224
    transforms.Normalize([0.485,0.456,0.406], [0.229,0.224,0.225])
])
base_ds = datasets.ImageFolder(root=DATA_ROOT, transform=norm_tfms)
num_classes = len(base_ds.classes)
print("Classes:", base_ds.classes)

targets = np.array(base_ds.targets)
indices = np.arange(len(base_ds))

# 80/10/10 split (stratified)
sss1 = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=SEED)
train_idx, temp_idx = next(sss1.split(indices, targets))
temp_targets = targets[temp_idx]
sss2 = StratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=SEED)
val_rel_idx, test_rel_idx = next(sss2.split(np.arange(len(temp_idx)), temp_targets))
val_idx, test_idx = temp_idx[val_rel_idx], temp_idx[test_rel_idx]

train_ds, val_ds, test_ds = Subset(base_ds, train_idx), Subset(base_ds, val_idx), Subset(base_ds, test_idx)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,
                          num_workers=NUM_WORKERS, pin_memory=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=True)
test_loader  = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=True)

print(f"Train: {len(train_ds)} | Val: {len(val_ds)} | Test: {len(test_ds)}")

# -------- Model Factory --------
def get_model(name, num_classes):
    if name == "resnet50":
        model = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
    elif name == "resnet101":
        model = models.resnet101(weights=models.ResNet101_Weights.DEFAULT)
    else:
        raise ValueError(f"Unknown model name: {name}")
    in_features = model.fc.in_features
    model.fc = nn.Linear(in_features, num_classes)
    return model

model = get_model(MODEL_NAME, num_classes).to(device)
print(f"Using model: {MODEL_NAME}")

# -------- Loss / Optim / Sched --------
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode="max", factor=0.5, patience=2
)
scaler = torch.cuda.amp.GradScaler(enabled=torch.cuda.is_available())

# -------- Train --------
best_val_acc = 0.0
history = {"train_loss":[], "val_loss":[], "train_acc":[], "val_acc":[]}

for epoch in range(1, EPOCHS+1):
    # train
    model.train()
    running_loss, correct, total = 0.0, 0, 0
    loop = tqdm(train_loader, desc=f"Epoch {epoch}/{EPOCHS} [Train]")

    for imgs, labels in loop:
        imgs, labels = imgs.to(device), labels.to(device)
        optimizer.zero_grad(set_to_none=True)

        with torch.cuda.amp.autocast(enabled=torch.cuda.is_available()):
            logits = model(imgs)
            loss   = criterion(logits, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()
        preds = logits.argmax(1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)
        loop.set_postfix(loss=loss.item(), acc=correct/max(1,total))

    train_loss = running_loss / len(train_loader)
    train_acc  = correct / total

    # validate (NO autocast!)
    model.eval()
    v_loss, v_correct, v_total = 0.0, 0, 0
    all_preds, all_labels, all_probs = [], [], []
    with torch.no_grad():
        vloop = tqdm(val_loader, desc=f"Epoch {epoch}/{EPOCHS} [Val]")
        for imgs, labels in vloop:
            imgs, labels = imgs.to(device), labels.to(device)
            logits = model(imgs)                    # 👈 FP32
            logits = torch.clamp(logits, -100, 100) # 👈 avoid overflow
            loss   = criterion(logits, labels)

            probs = torch.softmax(logits, dim=1)
            v_loss += loss.item()
            preds = logits.argmax(1)
            v_correct += (preds == labels).sum().item()
            v_total += labels.size(0)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

            vloop.set_postfix(loss=loss.item(), acc=v_correct/max(1,v_total))

    val_loss = v_loss / len(val_loader)
    val_acc  = v_correct / v_total

    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(train_acc)
    history["val_acc"].append(val_acc)

    print(f"✅ Epoch {epoch}: train_acc={train_acc:.4f} val_acc={val_acc:.4f} "
          f"| train_loss={train_loss:.4f} val_loss={val_loss:.4f}")

    scheduler.step(val_acc)

    # save best
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        ckpt_path = os.path.join(SAVE_DIR, f"{MODEL_NAME}_best.pth")
        torch.save({
            "model_state": model.state_dict(),
            "val_acc": best_val_acc,
            "epoch": epoch,
            "classes": base_ds.classes
        }, ckpt_path)
        print(f"💾 Saved best model → {ckpt_path}")

# -------- Final Test --------
print("\n=== TEST EVALUATION ===")
model.eval()
test_preds, test_labels, test_probs = [], [], []
with torch.no_grad():
    for imgs, labels in tqdm(test_loader, desc="Test"):
        imgs, labels = imgs.to(device), labels.to(device)
        logits = model(imgs)                    # 👈 FP32
        logits = torch.clamp(logits, -100, 100) # 👈 safe
        probs  = torch.softmax(logits, dim=1)
        preds  = logits.argmax(1)
        test_preds.extend(preds.cpu().numpy())
        test_labels.extend(labels.cpu().numpy())
        test_probs.extend(probs.cpu().numpy())

print("\nClassification Report (Test):")
print(classification_report(test_labels, test_preds, digits=4, target_names=base_ds.classes))

cm = confusion_matrix(test_labels, test_preds)
plt.figure(figsize=(8,6))
plt.imshow(cm, cmap="Blues")
plt.title(f"Confusion Matrix - Test ({MODEL_NAME})")
plt.xlabel("Predicted")
plt.ylabel("True")
for (i,j),v in np.ndenumerate(cm):
    plt.text(j, i, str(v), ha='center', va='center')
plt.xticks(ticks=np.arange(num_classes), labels=base_ds.classes, rotation=45, ha="right")
plt.yticks(ticks=np.arange(num_classes), labels=base_ds.classes)
plt.tight_layout()
plt.show()

# ---- AUC (OVR) ----
classes = list(range(num_classes))
y_true_bin = label_binarize(np.array(test_labels), classes=classes)
y_score = np.array(test_probs)
present_classes = np.unique(test_labels)
present_mask = np.isin(classes, present_classes)

def safe_auc(y_true, y_score, **kwargs):
    try: return roc_auc_score(y_true, y_score, **kwargs)
    except ValueError: return float("nan")

print(f"\nAUC (macro-OVR): {safe_auc(y_true_bin[:,present_mask], y_score[:,present_mask], average='macro', multi_class='ovr'):.4f}")
print(f"AUC (weighted-OVR): {safe_auc(y_true_bin[:,present_mask], y_score[:,present_mask], average='weighted', multi_class='ovr'):.4f}")
print(f"AUC (micro-OVR): {safe_auc(y_true_bin[:,present_mask], y_score[:,present_mask], average='micro', multi_class='ovr'):.4f}")

plt.figure(figsize=(8,6))
for c in present_classes:
    fpr, tpr, _ = roc_curve(y_true_bin[:, c], y_score[:, c])
    class_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{base_ds.classes[c]} (AUC={class_auc:.3f})")
plt.plot([0,1],[0,1],'--')
plt.title(f"ROC Curves (Test) — {MODEL_NAME}")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(fontsize=8)
plt.tight_layout()
plt.show()

# ---- Training curves ----
plt.figure(figsize=(11,4))
plt.subplot(1,2,1)
plt.plot(history["train_loss"], label="Train")
plt.plot(history["val_loss"], label="Val")
plt.title("Loss"); plt.legend()
plt.subplot(1,2,2)
plt.plot(history["train_acc"], label="Train")
plt.plot(history["val_acc"], label="Val")
plt.title("Accuracy"); plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Device: cuda
# Classes: ['ARMD', 'cataract', 'diabetic_retinopathy', 'glaucoma', 'normal']
# Train: 3782 | Val: 473 | Test: 473
# C:\Users\HP\AppData\Local\Temp\ipykernel_21892\4185418149.py:89: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=torch.cuda.is_available())
# Using model: resnet50
# Epoch 1/12 [Train]:   0%|                                                                      | 0/119 [00:00<?, ?it/s]C:\Users\HP\AppData\Local\Temp\ipykernel_21892\4185418149.py:105: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=torch.cuda.is_available()):
# Epoch 1/12 [Train]: 100%|█████████████████████████████████████| 119/119 [00:50<00:00,  2.38it/s, acc=0.804, loss=0.135]
# Epoch 1/12 [Val]: 100%|██████████████████████████████████████████| 15/15 [00:20<00:00,  1.35s/it, acc=0.911, loss=0.12]
# ✅ Epoch 1: train_acc=0.8038 val_acc=0.9112 | train_loss=0.6018 val_loss=0.2555
# 💾 Saved best model → checkpoints\resnet50_best.pth
# Epoch 2/12 [Train]: 100%|█████████████████████████████████████| 119/119 [00:36<00:00,  3.25it/s, acc=0.937, loss=0.432]
# Epoch 2/12 [Val]: 100%|████████████████████████████████████████| 15/15 [00:16<00:00,  1.12s/it, acc=0.924, loss=0.0627]
# ✅ Epoch 2: train_acc=0.9371 val_acc=0.9239 | train_loss=0.1797 val_loss=0.2298
# 💾 Saved best model → checkpoints\resnet50_best.pth
# Epoch 3/12 [Train]: 100%|███████████████████████████████████| 119/119 [00:36<00:00,  3.22it/s, acc=0.974, loss=0.00917]
# Epoch 3/12 [Val]: 100%|█████████████████████████████████████████| 15/15 [00:16<00:00,  1.10s/it, acc=0.92, loss=0.0983]
# ✅ Epoch 3: train_acc=0.9744 val_acc=0.9197 | train_loss=0.0755 val_loss=0.2376
# Epoch 4/12 [Train]: 100%|███████████████████████████████████| 119/119 [00:36<00:00,  3.26it/s, acc=0.991, loss=0.00351]
# Epoch 4/12 [Val]: 100%|█████████████████████████████████████████| 15/15 [00:16<00:00,  1.11s/it, acc=0.918, loss=0.081]
# ✅ Epoch 4: train_acc=0.9913 val_acc=0.9175 | train_loss=0.0303 val_loss=0.3373
# Epoch 5/12 [Train]: 100%|████████████████████████████████████| 119/119 [00:36<00:00,  3.29it/s, acc=0.993, loss=0.0329]
# Epoch 5/12 [Val]: 100%|█████████████████████████████████████████| 15/15 [00:16<00:00,  1.10s/it, acc=0.907, loss=0.322]
# ✅ Epoch 5: train_acc=0.9931 val_acc=0.9070 | train_loss=0.0204 val_loss=0.3564
# Epoch 6/12 [Train]: 100%|█████████████████████████████████████| 119/119 [00:36<00:00,  3.29it/s, acc=0.996, loss=0.659]
# Epoch 6/12 [Val]: 100%|█████████████████████████████████████████| 15/15 [00:17<00:00,  1.13s/it, acc=0.922, loss=0.148]
# ✅ Epoch 6: train_acc=0.9963 val_acc=0.9218 | train_loss=0.0181 val_loss=0.3178
# Epoch 7/12 [Train]: 100%|████████████████████████████████████| 119/119 [00:36<00:00,  3.26it/s, acc=0.996, loss=0.0224]
# Epoch 7/12 [Val]: 100%|████████████████████████████████████████| 15/15 [00:16<00:00,  1.12s/it, acc=0.928, loss=0.0707]
# ✅ Epoch 7: train_acc=0.9963 val_acc=0.9281 | train_loss=0.0127 val_loss=0.3004
# 💾 Saved best model → checkpoints\resnet50_best.pth
# Epoch 8/12 [Train]: 100%|████████████████████████████████████| 119/119 [00:36<00:00,  3.27it/s, acc=0.998, loss=0.0332]
# Epoch 8/12 [Val]: 100%|████████████████████████████████████████| 15/15 [00:16<00:00,  1.10s/it, acc=0.924, loss=0.0807]
# ✅ Epoch 8: train_acc=0.9984 val_acc=0.9239 | train_loss=0.0072 val_loss=0.3261
# Epoch 9/12 [Train]: 100%|███████████████████████████████████| 119/119 [00:36<00:00,  3.26it/s, acc=0.999, loss=0.00511]
# Epoch 9/12 [Val]: 100%|█████████████████████████████████████████| 15/15 [00:16<00:00,  1.10s/it, acc=0.92, loss=0.0197]
# ✅ Epoch 9: train_acc=0.9992 val_acc=0.9197 | train_loss=0.0044 val_loss=0.3345
# Epoch 10/12 [Train]: 100%|████████████████████████████████████| 119/119 [00:36<00:00,  3.28it/s, acc=0.998, loss=0.365]
# Epoch 10/12 [Val]: 100%|███████████████████████████████████████| 15/15 [00:16<00:00,  1.10s/it, acc=0.918, loss=0.0369]
# ✅ Epoch 10: train_acc=0.9984 val_acc=0.9175 | train_loss=0.0071 val_loss=0.3371
# Epoch 11/12 [Train]: 100%|██████████████████████████████████| 119/119 [00:36<00:00,  3.28it/s, acc=0.999, loss=0.00921]
# Epoch 11/12 [Val]: 100%|███████████████████████████████████████| 15/15 [00:16<00:00,  1.10s/it, acc=0.913, loss=0.0396]
# ✅ Epoch 11: train_acc=0.9987 val_acc=0.9133 | train_loss=0.0037 val_loss=0.3687
# Epoch 12/12 [Train]: 100%|█████████████████████████████████| 119/119 [00:36<00:00,  3.28it/s, acc=0.999, loss=0.000704]
# Epoch 12/12 [Val]: 100%|███████████████████████████████████████| 15/15 [00:16<00:00,  1.11s/it, acc=0.918, loss=0.0816]
# ✅ Epoch 12: train_acc=0.9989 val_acc=0.9175 | train_loss=0.0028 val_loss=0.3499
#
# === TEST EVALUATION ===
# Test: 100%|████████████████████████████████████████████████████████████████████████████| 15/15 [00:16<00:00,  1.10s/it]
# Classification Report (Test):
#                       precision    recall  f1-score   support
#
#                 ARMD     1.0000    1.0000    1.0000        51
#             cataract     0.9109    0.8846    0.8976       104
# diabetic_retinopathy     0.9910    1.0000    0.9955       110
#             glaucoma     0.8019    0.8416    0.8213       101
#               normal     0.8846    0.8598    0.8720       107
#
#             accuracy                         0.9091       473
#            macro avg     0.9177    0.9172    0.9173       473
#         weighted avg     0.9099    0.9091    0.9093       473
# AUC (macro-OVR): 0.9867
# AUC (weighted-OVR): 0.9855
# AUC (micro-OVR): 0.9900

# %% [markdown]
# ### ResNet-101

# %%
import os, random
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Subset
from torchvision import models, transforms, datasets

# %%
# ========= CONFIG =========
DATA_ROOT = r"preprocessed224_best"  
BATCH_SIZE = 32
EPOCHS = 12
LR = 1e-4
NUM_WORKERS = 2
SAVE_DIR = "checkpoints"
SEED = 42

# %%
# ==========================

os.makedirs(SAVE_DIR, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# -------- Reproducibility --------
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.benchmark = True

# -------- Dataset & Transforms --------
norm_tfms = transforms.Compose([
    transforms.ToTensor(),  # already 224x224 from preprocessing
    transforms.Normalize([0.485,0.456,0.406], [0.229,0.224,0.225])
])

base_ds = datasets.ImageFolder(root=DATA_ROOT, transform=norm_tfms)
num_classes = len(base_ds.classes)
print("Classes:", base_ds.classes)

targets = np.array(base_ds.targets)
indices = np.arange(len(base_ds))

# 80/10/10 split (stratified)
# 1) train vs temp (80/20)
sss1 = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=SEED)
train_idx, temp_idx = next(sss1.split(indices, targets))
# 2) temp -> val/test (50/50 of temp = 10% each overall)
temp_targets = targets[temp_idx]
sss2 = StratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=SEED)
val_rel_idx, test_rel_idx = next(sss2.split(np.arange(len(temp_idx)), temp_targets))
val_idx  = temp_idx[val_rel_idx]
test_idx = temp_idx[test_rel_idx]

train_ds = Subset(base_ds, train_idx)
val_ds   = Subset(base_ds, val_idx)
test_ds  = Subset(base_ds, test_idx)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,
                          num_workers=NUM_WORKERS, pin_memory=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=True)
test_loader  = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=True)

print(f"Train: {len(train_ds)} | Val: {len(val_ds)} | Test: {len(test_ds)}")
# Out:
# Device: cuda
# Classes: ['ARMD', 'cataract', 'diabetic_retinopathy', 'glaucoma', 'normal']
# Train: 3782 | Val: 473 | Test: 473

# %%
# -------- Model: ResNet-101 --------
def get_resnet101(num_classes):
    model = models.resnet101(weights=models.ResNet101_Weights.DEFAULT)
    in_features = model.fc.in_features
    model.fc = nn.Linear(in_features, num_classes)
    return model

model = get_resnet101(num_classes).to(device)

# -------- Loss / Optim / Sched --------
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode="max", factor=0.5, patience=2
)
scaler = torch.cuda.amp.GradScaler(enabled=torch.cuda.is_available())
# Out:
# C:\Users\Vedarth\AppData\Local\Temp\ipykernel_22996\1652118911.py:16: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=torch.cuda.is_available())

# %%
# -------- Train --------
best_val_acc = 0.0
history = {"train_loss":[], "val_loss":[], "train_acc":[], "val_acc":[]}

for epoch in range(1, EPOCHS+1):
    # train
    model.train()
    running_loss, correct, total = 0.0, 0, 0
    loop = tqdm(train_loader, desc=f"Epoch {epoch}/{EPOCHS} [Train]")
    for imgs, labels in loop:
        imgs, labels = imgs.to(device), labels.to(device)
        optimizer.zero_grad(set_to_none=True)
        with torch.cuda.amp.autocast(enabled=torch.cuda.is_available()):
            logits = model(imgs)
            loss = criterion(logits, labels)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()
        preds = logits.argmax(1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)
        loop.set_postfix(loss=loss.item(), acc=correct/max(1,total))

    train_loss = running_loss / len(train_loader)
    train_acc  = correct / total
    
    # validate
    model.eval()
    v_loss, v_correct, v_total = 0.0, 0, 0
    all_preds, all_labels, all_probs = [], [], []
    with torch.no_grad():
        vloop = tqdm(val_loader, desc=f"Epoch {epoch}/{EPOCHS} [Val]")
        for imgs, labels in vloop:
            imgs, labels = imgs.to(device), labels.to(device)

            # No autocast in validation to prevent FP16 overflow
            logits = model(imgs)
            
            # Optional: clamp logits to prevent overflow
            logits = torch.clamp(logits, -100, 100)
            
            loss = criterion(logits, labels)

            # Check for NaNs in loss (debugging)
            if not torch.isfinite(loss):
                print("⚠️ NaN loss detected in validation!")
                print("Max logit:", logits.abs().max().item())
                continue

            probs = torch.softmax(logits, dim=1)

            v_loss += loss.item()
            preds = logits.argmax(1)
            v_correct += (preds == labels).sum().item()
            v_total += labels.size(0)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

            vloop.set_postfix(loss=loss.item(), acc=v_correct / max(1, v_total))

    val_loss = v_loss / len(val_loader)
    val_acc  = v_correct / v_total

    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(train_acc)
    history["val_acc"].append(val_acc)

    print(f"✅ Epoch {epoch}: train_acc={train_acc:.4f} val_acc={val_acc:.4f} "
          f"| train_loss={train_loss:.4f} val_loss={val_loss:.4f}")

    scheduler.step(val_acc)

    # save best by val acc
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        ckpt_path = os.path.join(SAVE_DIR, "resnet101_best.pth")
        torch.save({
            "model_state": model.state_dict(),
            "val_acc": best_val_acc,
            "epoch": epoch,
            "classes": base_ds.classes
        }, ckpt_path)
        print(f"💾 Saved best model → {ckpt_path}")
# Out:
# Epoch 1/12 [Train]:   0%|          | 0/119 [00:00<?, ?it/s]
# C:\Users\Vedarth\AppData\Local\Temp\ipykernel_22996\3959576221.py:13: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=torch.cuda.is_available()):
# Epoch 1/12 [Train]: 100%|██████████| 119/119 [31:17<00:00, 15.78s/it, acc=0.817, loss=0.495]
# Epoch 1/12 [Val]: 100%|██████████| 15/15 [01:21<00:00,  5.42s/it, acc=0.882, loss=0.149]
# ✅ Epoch 1: train_acc=0.8173 val_acc=0.8816 | train_loss=0.5467 val_loss=0.3020
# 💾 Saved best model → checkpoints\resnet101_best.pth
# Epoch 2/12 [Train]: 100%|██████████| 119/119 [27:28<00:00, 13.85s/it, acc=0.945, loss=0.57]
# Epoch 2/12 [Val]: 100%|██████████| 15/15 [01:05<00:00,  4.38s/it, acc=0.924, loss=0.0603]
# ✅ Epoch 2: train_acc=0.9453 val_acc=0.9239 | train_loss=0.1602 val_loss=0.2415
# 💾 Saved best model → checkpoints\resnet101_best.pth
# Epoch 3/12 [Train]: 100%|██████████| 119/119 [27:26<00:00, 13.84s/it, acc=0.978, loss=0.0783]
# Epoch 3/12 [Val]: 100%|██████████| 15/15 [01:05<00:00,  4.40s/it, acc=0.918, loss=0.182]
# ✅ Epoch 3: train_acc=0.9781 val_acc=0.9175 | train_loss=0.0733 val_loss=0.2414
# Epoch 4/12 [Train]: 100%|██████████| 119/119 [27:29<00:00, 13.86s/it, acc=0.99, loss=0.153]
# Epoch 4/12 [Val]: 100%|██████████| 15/15 [01:06<00:00,  4.46s/it, acc=0.922, loss=0.104]
# ✅ Epoch 4: train_acc=0.9897 val_acc=0.9218 | train_loss=0.0390 val_loss=0.3209
# Epoch 5/12 [Train]: 100%|██████████| 119/119 [27:07<00:00, 13.68s/it, acc=0.983, loss=0.244]
# Epoch 5/12 [Val]: 100%|██████████| 15/15 [01:05<00:00,  4.38s/it, acc=0.899, loss=0.164]
# ✅ Epoch 5: train_acc=0.9828 val_acc=0.8985 | train_loss=0.0547 val_loss=0.3935
# Epoch 6/12 [Train]: 100%|██████████| 119/119 [27:17<00:00, 13.76s/it, acc=0.995, loss=0.172]
# Epoch 6/12 [Val]: 100%|██████████| 15/15 [01:05<00:00,  4.37s/it, acc=0.92, loss=0.222]
# ✅ Epoch 6: train_acc=0.9952 val_acc=0.9197 | train_loss=0.0209 val_loss=0.3115
# Epoch 7/12 [Train]: 100%|██████████| 119/119 [27:21<00:00, 13.79s/it, acc=0.998, loss=0.00644]
# Epoch 7/12 [Val]: 100%|██████████| 15/15 [01:06<00:00,  4.45s/it, acc=0.924, loss=0.0369]
# ✅ Epoch 7: train_acc=0.9981 val_acc=0.9239 | train_loss=0.0079 val_loss=0.3106
# Epoch 8/12 [Train]: 100%|██████████| 119/119 [27:15<00:00, 13.74s/it, acc=0.998, loss=0.0942]
# Epoch 8/12 [Val]: 100%|██████████| 15/15 [01:05<00:00,  4.40s/it, acc=0.918, loss=0.463]
# ✅ Epoch 8: train_acc=0.9979 val_acc=0.9175 | train_loss=0.0089 val_loss=0.3864
# Epoch 9/12 [Train]: 100%|██████████| 119/119 [27:22<00:00, 13.81s/it, acc=0.998, loss=0.0564]
# Epoch 9/12 [Val]: 100%|██████████| 15/15 [01:06<00:00,  4.45s/it, acc=0.913, loss=0.12]
# ✅ Epoch 9: train_acc=0.9984 val_acc=0.9133 | train_loss=0.0055 val_loss=0.3447
# Epoch 10/12 [Train]: 100%|██████████| 119/119 [05:52<00:00,  2.96s/it, acc=0.999, loss=0.0476]
# Epoch 10/12 [Val]: 100%|██████████| 15/15 [00:20<00:00,  1.35s/it, acc=0.915, loss=0.178]
# ✅ Epoch 10: train_acc=0.9989 val_acc=0.9154 | train_loss=0.0043 val_loss=0.3690
# Epoch 11/12 [Train]: 100%|██████████| 119/119 [06:17<00:00,  3.18s/it, acc=0.999, loss=0.134]
# Epoch 11/12 [Val]: 100%|██████████| 15/15 [01:06<00:00,  4.42s/it, acc=0.918, loss=0.234]
# ✅ Epoch 11: train_acc=0.9987 val_acc=0.9175 | train_loss=0.0048 val_loss=0.3873
# Epoch 12/12 [Train]: 100%|██████████| 119/119 [27:12<00:00, 13.71s/it, acc=0.999, loss=0.000326]
# Epoch 12/12 [Val]: 100%|██████████| 15/15 [01:06<00:00,  4.41s/it, acc=0.918, loss=0.209]
# ✅ Epoch 12: train_acc=0.9992 val_acc=0.9175 | train_loss=0.0029 val_loss=0.4027

# %%
# -------- Final Test Evaluation --------
print("\n=== TEST EVALUATION ===")
model.eval()
test_preds, test_labels, test_probs = [], [], []
with torch.no_grad():
    for imgs, labels in tqdm(test_loader, desc="Test"):
        imgs, labels = imgs.to(device), labels.to(device)
        with torch.cuda.amp.autocast(enabled=torch.cuda.is_available()):
            logits = model(imgs)
            probs = torch.softmax(logits, dim=1)
        preds = logits.argmax(1)

        test_preds.extend(preds.cpu().numpy())
        test_labels.extend(labels.cpu().numpy())
        test_probs.extend(probs.cpu().numpy())

print("\nClassification Report (Test):")
print(classification_report(test_labels, test_preds, digits=4, target_names=base_ds.classes))

cm = confusion_matrix(test_labels, test_preds)
plt.figure(figsize=(8,6))
plt.imshow(cm, cmap="Blues")
plt.title("Confusion Matrix - Test (ResNet-101)")
plt.xlabel("Predicted")
plt.ylabel("True")
for (i,j),v in np.ndenumerate(cm):
    plt.text(j, i, str(v), ha='center', va='center')
plt.xticks(ticks=np.arange(num_classes), labels=base_ds.classes, rotation=45, ha="right")
plt.yticks(ticks=np.arange(num_classes), labels=base_ds.classes)
plt.tight_layout()
plt.show()

# ---- AUC (OVR) ----
classes = list(range(num_classes))
y_true_bin = label_binarize(np.array(test_labels), classes=classes)
y_score = np.array(test_probs)
present_classes = np.unique(test_labels)
present_mask = np.isin(classes, present_classes)

def safe_auc(y_true, y_score, **kwargs):
    try:
        return roc_auc_score(y_true, y_score, **kwargs)
    except ValueError:
        return float("nan")

print(f"\nAUC (macro-OVR):    {safe_auc(y_true_bin[:,present_mask], y_score[:,present_mask], average='macro', multi_class='ovr'):.4f}")
print(f"AUC (weighted-OVR): {safe_auc(y_true_bin[:,present_mask], y_score[:,present_mask], average='weighted', multi_class='ovr'):.4f}")
print(f"AUC (micro-OVR):    {safe_auc(y_true_bin[:,present_mask], y_score[:,present_mask], average='micro', multi_class='ovr'):.4f}")

plt.figure(figsize=(8,6))
for c in present_classes:
    fpr, tpr, _ = roc_curve(y_true_bin[:, c], y_score[:, c])
    class_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{base_ds.classes[c]} (AUC={class_auc:.3f})")
plt.plot([0,1],[0,1],'--')
plt.title("ROC Curves (Test) — Resnet-101")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(fontsize=8)
plt.tight_layout()
plt.show()

# ---- Training curves ----
plt.figure(figsize=(11,4))
plt.subplot(1,2,1)
plt.plot(history["train_loss"], label="Train")
plt.plot(history["val_loss"], label="Val")
plt.title("Loss"); plt.legend()
plt.subplot(1,2,2)
plt.plot(history["train_acc"], label="Train")
plt.plot(history["val_acc"], label="Val")
plt.title("Accuracy"); plt.legend()
plt.tight_layout()
plt.show()
# Out:
# === TEST EVALUATION ===
# Test:   0%|          | 0/15 [00:00<?, ?it/s]C:\Users\Vedarth\AppData\Local\Temp\ipykernel_22996\3121292675.py:8: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=torch.cuda.is_available()):
# Test: 100%|██████████| 15/15 [02:50<00:00, 11.39s/it]
# Classification Report (Test):
#                       precision    recall  f1-score   support
#
#                 ARMD     1.0000    1.0000    1.0000        51
#             cataract     0.9519    0.9519    0.9519       104
# diabetic_retinopathy     1.0000    1.0000    1.0000       110
#             glaucoma     0.9158    0.8614    0.8878       101
#               normal     0.8938    0.9439    0.9182       107
#
#             accuracy                         0.9471       473
#            macro avg     0.9523    0.9514    0.9516       473
#         weighted avg     0.9474    0.9471    0.9470       473
# AUC (macro-OVR):    0.9910
# AUC (weighted-OVR): 0.9902
# AUC (micro-OVR):    0.9931
